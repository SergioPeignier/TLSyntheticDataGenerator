# %%
# %matplotlib inline

# %%
import pickle
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn import tree

# %%
import graphviz 
def plot_tree(clf,feature_names, class_names):
    dot_data = tree.export_graphviz(clf, out_file=None, 
                             feature_names=feature_names,  
                             class_names=class_names,  
                             filled=True,rounded=True,  
                             special_characters=True)  
    graph = graphviz.Source(dot_data)  
    return graph
def save_tree(graph,name):
    graph.render(name, view=False)

# %% [markdown]
# # Load Results

# %%
ser_results_large_sample = pd.read_csv("ser_results_large_sample.csv",index_col=0,header=0)
ser_results_small_sample = pd.read_csv("ser_results_small_sample.csv",index_col=0,header=0)
source_results_large_sample = pd.read_csv("source_results_large_sample.csv",index_col=0,header=0)
source_results_small_sample = pd.read_csv("source_results_small_sample.csv",index_col=0,header=0)
strut_results_large_sample = pd.read_csv("strut_results_large_sample.csv",index_col=0,header=0)
strut_results_small_sample = pd.read_csv("strut_results_small_sample.csv",index_col=0,header=0)

# %%
strut_results_small_sample.index = [ index.split("df_")[-1] for index in strut_results_small_sample.index]
strut_results_large_sample.index = [ index.split("df_")[-1] for index in strut_results_large_sample.index]

ser_results_small_sample.index = [ index.split("df_")[-1] for index in ser_results_small_sample.index]
ser_results_large_sample.index = [ index.split("df_")[-1] for index in ser_results_large_sample.index]

source_results_small_sample.index = [ index.split("df_")[-1] for index in source_results_small_sample.index]
source_results_large_sample.index = [ index.split("df_")[-1] for index in source_results_large_sample.index]

# %%
fig, ax = plt.subplots(figsize=(4.5,8))
sns.heatmap(strut_results_large_sample,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4.5,8))
sns.heatmap(ser_results_large_sample,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4.5,8))
sns.heatmap(source_results_large_sample,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4.5,8))
sns.heatmap(strut_results_small_sample,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4.5,8))
sns.heatmap(ser_results_small_sample,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
plt.tight_layout()

# %%
fig, ax = plt.subplots(figsize=(4.5,8))
sns.heatmap(source_results_small_sample,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
plt.tight_layout()

# %%
degradation_strut = (strut_results_small_sample - strut_results_large_sample).abs()

# %%
fig, ax = plt.subplots(figsize=(3.5,8))
sns.heatmap(degradation_strut,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)

# %%
degradation_ser = (ser_results_small_sample - ser_results_large_sample).abs()

# %%
fig, ax = plt.subplots(figsize=(3.5,8))
sns.heatmap(degradation_ser,ax=ax)
_=plt.xticks(fontsize=12)
_=plt.yticks(fontsize=10)
